# %%
import os
from openai import OpenAI
import openai

# %%
openai.api_base = 'http://0.0.0.0:8000/v1'
base_url = "http://127.0.0.1:8000/v1/"
client = OpenAI(api_key="EMPTY", base_url=base_url)

# %%
prompt_1 = """
    你是一个经验丰富的呼吸科医生。患者已经做过了CAC（循环染色体异常细胞检测）与CTAI（肺部CT扫描与肺结节风险评估）检测。
    请根据患者的检查结果，给出综合风险评估与随访时间建议报告。
    报告格式为：
    "本次检出循环异常细胞xx个，提示xx风险。CTAI评估结节风险为xx，提示xx风险。结节大小为xx，该结节为首次发现/较上次对比xx变化。
    综合以上信息，该患者综合风险为xx风险，建议密切观察，xx月复查胸部CT对比随访/建议积极治疗（如手术切除）/建议抗炎治疗（两周）后复查胸部CT随访对比。
    "
    以下为参考信息：
    "CAC中高风险区间，CTAI未达高风险区间，应对患者进行定期随访，3-6个月复查胸部CT，同时CTAI进行随访对比分析。"
"""
user_content = """
CAC:8个；
CAC风险等级：中风险；
CTAI：58.86%；
CTAI风险等级：低风险；
结节尺寸：6.74mm；
随访变化：首次发现；
综合风险评估：中风险；
随访建议：3个月
"""
messages = [
    {
        "role":"system",
        "content":prompt_1
    },
    {
        "role":"user",
        "content":user_content
    }
]
response = client.chat.completions.create(
    model="glm-4",
    messages=messages,
    stream=False,
    max_tokens=512,
    temperature=0,
    presence_penalty=1.2,
    top_p=1,
)
if response and response.choices:
    print("response: ",response.choices[0].message.content)
    print("success")
else:
    print('False')
# Out:
# response:  本次检出循环异常细胞8个，提示中风险。CTAI评估结节风险为58.86%，提示低风险。结节大小为6.74mm，该结节为首次发现。
#
# 综合以上信息，该患者综合风险为中风险。建议密切观察，3个月后复查胸部CT对比随访。
# success

# %%
prompt_2 = """
    你是一个经验丰富的呼吸科医生。患者已经做过了CAC（循环染色体异常细胞检测）与CTAI（肺部CT扫描与肺结节风险评估）检测。
    请根据患者的检查结果，给出综合风险评估与随访时间建议报告。
    报告格式为：
    "本次检出循环异常细胞xx个，提示xx风险。CTAI评估结节风险为xx，提示xx风险。结节大小为xx，该结节为首次发现/较上次对比xx变化。
    综合以上信息，该患者综合风险为xx风险，建议密切观察，xx月复查胸部CT对比随访/建议积极治疗（如手术切除）/建议抗炎治疗（两周）后复查胸部CT随访对比。
    "
    以下为参考信息：
    "CAC高风险区间，CTAI未达高风险区间，建议抗炎治疗（两周）后3个月复查胸部CT，同时进行CTAI随访对比。如有结节增大、密度增高、实性成分增加等，可建议积极治疗，如果没有结节增大、密度增高、实性成分增加等，应对患者进行密切随访，每3个月复查胸部CT，连续3-4次，随访观察过程中出现结节恶性倾向增大（结节增大、密度增高、实性成分增加或出现下列征象一项以上时：结节分叶、毛刺、胸膜牵拉、血管集束、空泡征等，建议积极治疗。"
"""
user_content_2 = """
CAC:18个；
CAC风险等级：高风险；
CTAI：60.26%；
CTAI风险等级：低风险；
结节尺寸：11.40mm；
随访变化：首次发现；
综合风险评估：中高风险；
随访建议：3个月
"""
messages = [
    {
        "role":"system",
        "content":prompt_2
    },
    {
        "role":"user",
        "content":user_content_2
    }
]
response = client.chat.completions.create(
    model="glm-4",
    messages=messages,
    stream=True,
    max_tokens=512,
    temperature=0,
    presence_penalty=1.2,
    top_p=1,
)
if response:
    for chunk in response:
        content = chunk.choices[0].delta.content
        finish_reason = chunk.choices[0].finish_reason
        print(content, end='')
else:
    print('Error')
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File /data/zhenyu/anaconda3/envs/llama_factory/lib/python3.10/site-packages/httpcore/_exceptions.py:10, in map_exceptions(map)
#       9 try:
# ---> 10     yield
#      11 except Exception as exc:  # noqa: PIE786
#
# File /data/zhenyu/anaconda3/envs/llama_factory/lib/python3.10/site-packages/httpcore/_backends/sync.py:100, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#      99 with map_exceptions(exc_map):
# --> 100     sock = socket.create_connection(
#     101         address,
#     102         timeout,
#     103         source_address=source_address,
#     104     )
#     105     for option in socket_options:
#
# File /data/zhenyu/anaconda3/envs/llama_factory/lib/python3.10/socket.py:845, in create_connection(address, timeout, source_address)
#     844 try:
# --> 845     raise err
# ...

# %%
prompt_3 = """
    你是一个经验丰富的呼吸科医生。患者已经做过了CAC（循环染色体异常细胞检测）与CTAI（肺部CT扫描与肺结节风险评估）检测。
    请根据患者的检查结果，给出综合风险评估与随访时间建议报告。
    报告格式为：
    "本次检出循环异常细胞xx个，提示xx风险。CTAI评估结节风险为xx，提示xx风险。结节大小为xx，该结节为首次发现/较上次对比xx变化。
    综合以上信息，该患者综合风险为xx风险，建议密切观察，xx月复查胸部CT对比随访/建议积极治疗（如手术切除）/建议抗炎治疗（两周）后复查胸部CT随访对比。
    "
    以下为参考信息：
    "良性结节的可能性较大，建议年度体检，12个月复查胸部CT。如果结节大于15mm，或患者焦虑明显、要求治疗意愿明显，可考虑手术干预，但术后病理良性结节概率较高。"
"""
user_content_3 = """
CAC:1个；
CAC风险等级：低风险；
CTAI：30%；
CTAI风险等级：低风险；
结节尺寸：23.42mm；
随访变化：较前增大；
综合风险评估：中风险；
随访建议：3个月
"""
messages = [
    {
        "role":"system",
        "content":prompt_3
    },
    {
        "role":"user",
        "content":user_content_3
    }
]
response = client.chat.completions.create(
    model="glm-4",
    messages=messages,
    stream=True,
    max_tokens=512,
    temperature=0,
    presence_penalty=1.2,
    top_p=1,
)
if response:
    for chunk in response:
        content = chunk.choices[0].delta.content
        finish_reason = chunk.choices[0].finish_reason
        print(content, end='')
else:
    print('Error')

# %%
prompt_4 = """
    你是一个经验丰富的呼吸科医生。患者已经做过了CAC（循环染色体异常细胞检测）与CTAI（肺部CT扫描与肺结节风险评估）检测。
    请根据患者的检查结果，给出综合风险评估与随访时间建议报告。
    报告格式为：
    "本次检出循环异常细胞xx个，提示xx风险。CTAI评估结节风险为xx，提示xx风险。结节大小为xx，该结节为首次发现/较上次对比xx变化。
    综合以上信息，该患者综合风险为xx风险，建议密切观察，xx月复查胸部CT对比随访/建议积极治疗（如手术切除）/建议抗炎治疗（两周）后复查胸部CT随访对比。
    "
    以下为参考信息：
    "CAC高风险区间，CTAI未达高风险区间，建议抗炎治疗（两周）后3个月复查胸部CT，同时进行CTAI随访对比。如有结节增大、密度增高、实性成分增加等，可建议积极治疗，如果没有结节增大、密度增高、实性成分增加等，应对患者进行密切随访，每3个月复查胸部CT，连续3-4次，随访观察过程中出现结节恶性倾向增大（结节增大、密度增高、实性成分增加或出现下列征象一项以上时：结节分叶、毛刺、胸膜牵拉、血管集束、空泡征等，建议积极治疗。"
"""
user_content_4 = """
CAC:2个；
CAC风险等级：低风险；
CTAI：57%；
CTAI风险等级：低风险；
结节尺寸：6.4mm；
随访变化：首次发现；
综合风险评估：中低风险；
随访建议：6个月
"""
messages = [
    {
        "role":"system",
        "content":prompt_4
    },
    {
        "role":"user",
        "content":user_content_4
    }
]
response = client.chat.completions.create(
    model="glm-4",
    messages=messages,
    stream=True,
    max_tokens=512,
    temperature=0,
    presence_penalty=1.2,
    top_p=1,
)
if response:
    for chunk in response:
        content = chunk.choices[0].delta.content
        finish_reason = chunk.choices[0].finish_reason
        print(content, end='')
else:
    print('Error')
